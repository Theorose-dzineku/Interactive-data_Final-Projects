# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns 
import json

# %%
df = pd.read_csv("DI Hub Equipment Reservations 2.csv")

# %%
df.head()
# Out:
#     Equipment     Start Time       End Time  Check-In Time Room Number  \
# 0  3D Scanner   2/5/24 10:00   2/5/24 11:00   2/5/24 11:21         NaN
# 1  3D Scanner   2/5/24 11:00   2/5/24 12:00   2/5/24 11:21         NaN
# 2  3D Scanner   2/5/24 12:00   2/5/24 13:00   2/5/24 12:44         NaN
# 3  3D Scanner   2/7/24 10:00   2/7/24 11:00   2/7/24 10:58         NaN
# 4  3D Scanner  3/13/24 13:00  3/13/24 14:00  3/13/24 13:00         NaN
#
#   Proficiency skills     Location
# 0  Beginner friendly  Frist floor
# 1  Beginner friendly  Frist floor
# 2  Beginner friendly  Frist floor
# 3  Beginner friendly  Frist floor
# 4  Beginner friendly  Frist floor

# %%
df.tail()
# Out:
#              Equipment     Start Time       End Time  Check-In Time  \
# 914     XR Workstation  3/20/25 12:00  3/20/25 13:00  3/20/25 12:03
# 915  XR_Collaboratory    3/4/25 13:00   3/4/25 14:00            NaN
# 916  XR_Collaboratory    3/5/25 13:00   3/5/25 14:00   3/5/25 13:05
# 917  XR_Collaboratory   3/21/25 12:00  3/21/25 13:00            NaN
# 918   XR_Collaboratory  3/21/25 13:00  3/21/25 14:00            NaN
#
#     Room Number Proficiency skills      Location
# 914         NaN  Beginner friendly  second floor
# 915     DIH 142  Beginner friendly  second floor
# 916     DIH 143  Beginner friendly  second floor
# 917     DIH 144  Beginner friendly  second floor
# 918     DIH 145  Beginner friendly  second floor

# %%
df.shape
# Out:
# (919, 7)

# %%
sns.scatterplot(data=df, x="Equipment", y="Room Number")
# Out:
# <Axes: xlabel='Equipment', ylabel='Room Number'>

# %% [markdown]
# while I think some of my variable might work with a scatterplot, I don't believe so paring Equipment and Room number will work well. I am leaving this in for now but in my final work, I will not be keeping this. I also intend to explore as many ways of visualizing my data until I find the one that best represents my data

# %%
df.columns
# Out:
# Index(['Equipment', 'Start Time', 'End Time', 'Check-In Time', 'Room Number',
#        'Proficiency skills', 'Location'],
#       dtype='object')

# %%
sns.relplot(data=df, x="Equipment", y="Check-In Time", col="Location", kind="scatter", hue="Proficiency skills", alpha=0.5)

# %% [markdown]
# While reflecting on this, I still feel a lot is going on in just one graph. For example, the 'check-in Time' does not look clear, similar to the Equipment portion. In terms of data visualization, this is not a good way to present my data.

# %%
sns.catplot(data=df, x="'Start Time", y= "End Time", kind= "bar")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 sns.catplot(data=df, x="'Start Time", y= "End Time", kind= "bar")
#
# File /opt/anaconda3/envs/indata_sp25/lib/python3.12/site-packages/seaborn/categorical.py:2782, in catplot(data, x, y, hue, row, col, kind, estimator, errorbar, n_boot, seed, units, weights, order, hue_order, row_order, col_order, col_wrap, height, aspect, log_scale, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    2779     elif x is not None and y is not None:
#    2780         raise ValueError("Cannot pass values for both `x` and `y`.")
# -> 2782 p = Plotter(
#    2783     data=data,
#    2784     variables=dict(
#    2785         x=x, y=y, hue=hue, row=row, col=col, units=units, weight=weights
#    2786     ),
#    2787     order=order,
# ...

# %% [markdown]
# I got the above error multiple times. I tried to plot my variable in many ways to get good visuals but I am struggling to get a good pairing for my variables.

# %%
sns.countplot(data=df, x="Equipment", palette= "icefire", hue= "Equipment")
# Out:
# <Axes: xlabel='Equipment', ylabel='count'>

# %% [markdown]
# I like the way the bars are showing but I still don't like how the vertical axis is looking. It looks crowded. I am thinking perhaps re-cleaning my data and creating separate slots for each piece of equipment might solve my challenge.

# %%
sns.catplot(df, kind= 'bar', x= 'Location', y= 'Equipment', fill = False, saturation = .3)

# %% [markdown]
# So, the above figure is clearer, better, and a bit closer to what I am looking for. It clearly shows the types of equipment available. I see this as a breakthrough from the visuals I have so far.

# %%
sns.catplot(df, kind= 'box', x= 'Location', y= 'Equipment', col= 'Proficiency skills', hue= 'Room Number', fill = False, saturation = .3)
# Out:
# /opt/anaconda3/envs/indata_sp25/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Aside from the warning in red at the top of the figure, I feel 'box' may not be the best way to show all this.

# %%
sns.catplot(df, kind= 'bar', x= 'Location', y= 'Equipment', col= 'Proficiency skills', hue= 'Room Number', fill = False, saturation = .2)
# Out:
# /opt/anaconda3/envs/indata_sp25/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Overall, in milestone 2, I was able to identify other ways to better present my data. I feel I need to clean my data again so I am able to get good visuals. In the coming week, I will be using Plotly more to see how I can generate other figures that are more appropriate.
